# %%
from faker import Faker
fake = Faker('es_ES')
fake.name()
from faker import Factory
import pandas as pd
import random
import os
import array as arr
from collections import Counter

# %%
arrem = []
nd = pd.DataFrame (
     {
        "Nombre":[fake.name()],
        "Correo":[fake.email()],
        "Direccion":[fake.country()],
        
      }
)

for i in range(random.randint(25,50)):
    stuff = [fake.name()
        , fake.email()
        , fake.country()]
    nd.loc[i] = [item for item in stuff]
    email = fake.email()
    global host
    host = email.split('@')[1]
    arrem.append(host)
    

df = nd
df
# Out:
#                                  Nombre                              Correo  \
# 0   Fernando Miguel Ángel Mariño Méndez              pablogallart@gmail.com
# 1                 Jaime Giménez Salcedo                   cmari@hotmail.com
# 2              Alejandro Castilla Plaza                 tescudero@yahoo.com
# 3                     Rosa Arroyo Perea          arnaizjose-maria@yahoo.com
# 4                  Salvador del Iriarte      francisco-javier77@hotmail.com
# 5           Enrique Torrecilla Palomino            jose-ramon43@huertas.net
# 6                   Laura Gámez Santana        rodriguezdomingo@hotmail.com
# 7                          Angela Tomas                npelaez@escudero.com
# 8                  Miriam Moya-Gargallo  gallardocarlos@priego-corbacho.com
# 9           Pedro Adrián Esteban Castro             jesusmartinez@gmail.com
# 10                Rosario Valls Herranz                 wmiralles@gmail.com
# 11           Cristian Bellido Capdevila            narvaezadriana@yahoo.com
# 12                       Agustín Zurita            ismaelcrespo@hotmail.com
# 13             Victor Manuel Niño Valls            diegoiniguez@barbera.com
# 14                Aurora Domingo Rivera           beatrizcollado@arranz.com
# 15               Dolores Quero Salvador           nfrias@bellido-pelaez.com
# 16            Concepción Sales Vendrell           franciscomolins@yahoo.com
# 17                       Trinidad Peñas                 kromero@becerra.net
# 18                         Hugo Jiménez                qbaquero@jimenez.com
# 19                 Marc Villalba Andrés                javier14@hotmail.com
# 20                 Nuria Marín-Gilabert               pedrotrillo@yahoo.com
# 21               Roberto Baños Menendez                 alfredo99@yahoo.com
# 22                        Olga de Galan              josefasans@marquez.com
# 23         Jose Ignacio Ortuño-Menéndez                 pparedes@criado.net
# 24                     Pablo de Estevez                hugorico@hotmail.com
# 25       Juan Carlos Valderrama Cazorla                 ricardo40@jorda.com
# 26                 Concepción de Canals                 lourdes08@gmail.com
# 27          Josefina Hernandez-Espinosa         isabelballesteros@lopez.com
# 28                Daniel Rocamora Núñez             marinarevilla@gmail.com
# 29                      Alicia de Baños          begonasalmeron@lorenzo.com
# 30                    Celia Coll Peláez          gargallomilagros@gmail.com
# 31                  Antonio Mur-Ródenas                  julian05@gmail.com
# 32                       Patricia Pazos          campillodaniel@hotmail.com
# 33                      Jose Reyes-Moll                   acamara@saura.com
# 34                     Julian Sanmiguel                fvalcarcel@yahoo.com
#
#                           Direccion
# 0                     Liechtenstein
# 1                          Suriname
# 2                   República Checa
# 3                           Granada
# 4                           Rumania
# 5                             Suiza
# 6                     Sudán del Sur
# 7                          Zimbabwe
# 8                           Uruguay
# 9                          Suriname
# 10                       Luxemburgo
# 11                          Argelia
# 12                          Namibia
# 13                          Rumania
# 14                            Malta
# 15                          Andorra
# 16                           Uganda
# 17                          Bolivia
# 18           Emiratos Árabes Unidos
# 19                        Finlandia
# 20                        Venezuela
# 21      República Unida de Tanzanía
# 22                      Timor-Leste
# 23                             Chad
# 24                        Kazajstán
# 25                          Ucrania
# 26                       Eslovaquia
# 27                         Lituania
# 28                             Chad
# 29                         Paraguay
# 30                        Venezuela
# 31                          Estonia
# 32                             Omán
# 33                          Malasia
# 34  República Democrática del Congo

# %%
print(arrem)
# Out:
# ['quesada.net', 'yahoo.com', 'yahoo.com', 'gmail.com', 'hotmail.com', 'yahoo.com', 'saavedra.net', 'gaya.biz', 'yahoo.com', 'alcala.biz', 'gmail.com', 'mariscal.com', 'verdu.com', 'gmail.com', 'garmendia-sacristan.info', 'bello.com', 'roman.com', 'rincon.com', 'hotmail.com', 'barrios.info', 'arino.com', 'yahoo.com', 'gmail.com', 'gmail.com', 'hotmail.com', 'yahoo.com', 'gmail.com', 'gmail.com', 'guzman.org', 'gmail.com', 'urrutia.com', 'hotmail.com', 'hotmail.com', 'gmail.com', 'gmail.com']

# %%
arr = {i:arrem.count(i) for i in arrem}
arr
# Out:
# {'quesada.net': 1,
#  'yahoo.com': 6,
#  'gmail.com': 10,
#  'hotmail.com': 5,
#  'saavedra.net': 1,
#  'gaya.biz': 1,
#  'alcala.biz': 1,
#  'mariscal.com': 1,
#  'verdu.com': 1,
#  'garmendia-sacristan.info': 1,
#  'bello.com': 1,
#  'roman.com': 1,
#  'rincon.com': 1,
#  'barrios.info': 1,
#  'arino.com': 1,
#  'guzman.org': 1,
#  'urrutia.com': 1}

# %%
da = pd.Series(arr).to_frame()
db = da.reset_index()
db.columns = ['Correos', 'Cantidad']
db
# Out:
#                      Correos  Cantidad
# 0                quesada.net         1
# 1                  yahoo.com         6
# 2                  gmail.com        10
# 3                hotmail.com         5
# 4               saavedra.net         1
# 5                   gaya.biz         1
# 6                 alcala.biz         1
# 7               mariscal.com         1
# 8                  verdu.com         1
# 9   garmendia-sacristan.info         1
# 10                 bello.com         1
# 11                 roman.com         1
# 12                rincon.com         1
# 13              barrios.info         1
# 14                 arino.com         1
# 15                guzman.org         1
# 16               urrutia.com         1
