# %%
import pandas as pd
import os

# %%
from IPython.core.display import display, HTML
display(HTML('<h1>Datos Ventas de Sistemas Operativos</h1>'
            '<style>h1 {color: red;} </style>'))
new_dataframe = pd.DataFrame (
     {
        "Sistemas":['Ubuntu','Linux','Mac','Windows'],
        "Tipo":['Libre','Libre','Propietario','Propietario'],
        "Unidades":[150000,250000,100000,750000],
        "Porcentaje":['15%','25%','10%','50%']
        
      }
)

new_dataframe
# Out:
# <h1>Datos Ventas de Sistemas Operativos</h1><style>h1 {color: red;} </style>
#   Sistemas         Tipo  Unidades Porcentaje
# 0   Ubuntu        Libre    150000        15%
# 1    Linux        Libre    250000        25%
# 2      Mac  Propietario    100000        10%
# 3  Windows  Propietario    750000        50%

# %%
display(HTML('<h1>Tabla Ventas de Sistemas Operativos</h1>'));
new_dataframe.plot(x='Sistemas', y='Unidades', kind='bar');
# Out:
# <h1>Tabla Ventas de Sistemas Operativos</h1>

# %%
# %%HTML
# <img src="https://ih0.redbubble.net/image.343436746.5737/flat,550x550,075,f.jpg">
# <h1>FUNSIONA</h1>
# Out:
# <img src="https://ih0.redbubble.net/image.343436746.5737/flat,550x550,075,f.jpg">
# <h1>FUNSIONA</h1>

# %%
from faker import Faker
fake = Faker()
fake.name()
for _ in range(10):
  print(fake.name())
# Out:
# Johnny Jones
# Diana Lee
# Eric Hernandez
# Jamie Walker
# Jerry Fisher
# Faith Walker
# Rachel Howard
# Lauren Clark
# Karen Foster
# Jessica Miller

# %%
new_dataframe = pd.DataFrame (
     {
        "Sistemas":[fake.name()],
        "Tipo":[fake.email()],
        
      }
)

new_dataframe
# Out:
#        Sistemas                       Tipo
# 0  Juan Goodman  qsmith@wilson-dorsey.info

# %%
from faker import Factory
import pandas as pd
import random

df = pd.DataFrame(columns=('Ciudad'
    , 'Estado'
    , 'Poblacion'))

for i in range(50):
    stuff = [fake.city()
        , fake.state()
        , random.randint(500000,3000000)]
    df.loc[i] = [item for item in stuff]

df
# Out:
#                Ciudad          Estado Poblacion
# 0         South Andre            Iowa   1585271
# 1     New Christopher        Arkansas    941392
# 2         Harveymouth         Georgia   1632032
# 3          West Brian         Georgia   2218746
# 4          Lake Kayla        Michigan   1658880
# 5            Markport         Florida    815185
# 6         Bergermouth        Delaware   2422811
# 7            Raymouth       Louisiana   2544978
# 8    South Heidimouth   West Virginia   2131431
# 9          Lake Steve      California    626680
# 10         New Tracey       Minnesota   2370325
# 11          Mollyport         Montana   1958892
# 12          Emilytown    South Dakota   1953276
# 13         Mariahfort        Arkansas    501683
# 14         Millerside   West Virginia   2032691
# 15          West Cody        Kentucky   2076447
# 16          Brownbury         Vermont   1740559
# 17      South Allison       Tennessee   2084535
# 18      North Felicia   New Hampshire   2373009
# 19   East Matthewstad        New York   1066339
# 20       Lake Zachary    South Dakota   1888678
# 21   North Jasonmouth          Kansas   1987506
# 22          Jennaview      New Mexico    717671
# 23     Port Codyhaven  North Carolina   1462531
# 24    South Ashleyton     Connecticut   2604629
# 25          Port Dana        Maryland   2188438
# 26          Hallmouth        Arkansas   1513983
# 27     Port Mariatown       Tennessee   1537557
# 28          New Sarah  South Carolina   2205051
# 29         Lake Karen        Illinois   1042256
# 30          Rochafort            Ohio   1450807
# 31          Tanyafurt  North Carolina   2589240
# 32         Ashleystad        Maryland   1369436
# 33     East Wendyside        New York   2291623
# 34      North Michael    Rhode Island   2027241
# 35         Stoneville          Hawaii    712693
# 36         Medinabury        Missouri   2415663
# 37    East Sharonview        New York    631898
# 38       North Rickey          Alaska   1822239
# 39       Tiffanyburgh        Michigan   1079965
# 40     North Jennifer   New Hampshire   1270185
# 41     East Tonyastad        Virginia   2957647
# 42    Port Martinside          Hawaii   1502863
# 43          Whiteberg         Arizona   2605252
# 44    South Wendyfort          Nevada   1931759
# 45  West Michaelmouth   Massachusetts    927177
# 46   Lake Carlosmouth         Vermont   2371236
# 47    Lake Racheltown    Pennsylvania    690015
# 48        South Peter      Washington    980730
# 49        Leonardfort     Connecticut   2298979
