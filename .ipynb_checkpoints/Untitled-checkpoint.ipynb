# %%
from faker import Faker
fake = Faker()
fake.name()
from faker import Factory
import pandas as pd
import random
import os
import array as arr
from collections import Counter
arrem = []

# %%
nd = pd.DataFrame (
     {
        "Nombre":[fake.name()],
        "Correo":[fake.email()],
        
      }
)

for i in range(random.randint(25,50)):
    stuff = [fake.name()
        , fake.email()]
    nd.loc[i] = [item for item in stuff]
    email = fake.email()
    global host
    host = email.split('@')[1]
    arrem.append(host)
    

df = nd

# %%
Prueba = df.groupby('Correo').Correo.count()
Prueba
# Out:
# Correo
# amy91@hotmail.com                  1
# bgarcia@cruz.biz                   1
# bmckinney@li.com                   1
# bradleygabrielle@wells.com         1
# brookemoreno@gmail.com             1
# canderson@hotmail.com              1
# cbennett@washington.com            1
# cflores@yahoo.com                  1
# christopherwells@yahoo.com         1
# cowanbryan@yahoo.com               1
# davissarah@gmail.com               1
# douglas44@hotmail.com              1
# duaneblackwell@davis.net           1
# edward92@yahoo.com                 1
# eric06@evans.com                   1
# ericrice@gmail.com                 1
# iallen@smith.com                   1
# iboyd@alexander.com                1
# isabella92@yahoo.com               1
# jacobcamacho@harrison.biz          1
# jessica94@miller.com               1
# juliafleming@tate.net              1
# karenyoung@gmail.com               1
# lcarter@parker.com                 1
# lmorrison@gmail.com                1
# lowecatherine@gmail.com            1
# michaeldavis@griffin.com           1
# reedaustin@frazier-williams.biz    1
# ricardocarson@gmail.com            1
# richardsonwilliam@gmail.com        1
# rileyclay@hotmail.com              1
# rjones@yahoo.com                   1
# robin22@porter-gonzalez.info       1
# samantha28@hotmail.com             1
# sanchezgeorge@hotmail.com          1
# sarah91@may.com                    1
# scottmurray@hotmail.com            1
# taylorashlee@yahoo.com             1
# vhuff@black.biz                    1
# victoria11@yahoo.com               1
# vwilson@hogan.com                  1
# yferguson@jacobs-archer.info       1
# Name: Correo, dtype: int64

# %%
s = 'wrobinson@gmail.com'
b = s.split('@')[1]
b
# Out:
# 'gmail.com'

# %%
df
# Out:
#               Nombre                          Correo
# 0        Brian Allen           phillippark@gmail.com
# 1         Seth Jones  katherine41@summers-durham.org
# 2       Sarah Golden      xpowell@jimenez-porter.biz
# 3       Michael Ward           juliesnyder@gmail.com
# 4       Adrian Poole      gjohnson@hart-friedman.com
# 5     Stephen Brooks           calebdeleon@gmail.com
# 6       Aaron Oliver   harrisalyssa@brown-steele.biz
# 7     William Harper          jamesdouglas@gmail.com
# 8        Angela Tran       nicholas44@shaw-mason.com
# 9    Brandon Johnson         collinsrodney@gmail.com
# 10   Heidi Nelson MD             troy73@ramirez.info
# 11       Alyssa Duke             joseph14@franco.net
# 12      Amanda Lopez           ricardo98@hotmail.com
# 13      Ryan Simpson               gsnyder@white.com
# 14     Nicholas Love             jessica27@gmail.com
# 15     Natasha Allen   jill12@martinez-hernandez.com
# 16        Sara Young          thomasmonica@gmail.com
# 17     Michael Chang           elaine41@gonzales.com
# 18  Kimberly Daniels      brianbrewer@mclaughlin.com
# 19    Antonio Wilson              erin32@hotmail.com
# 20         Joel Rose             karen62@hotmail.com
# 21    Gregory Orozco        zsimpson@smith-mills.com
# 22       Elijah Hall           suzanne99@mcguire.org
# 23     Dennis Cooper       spencematthew@bridges.com
# 24     Carlos Ibarra               hkidd@hotmail.com
# 25         Lisa Bell                 amy49@huynh.net

# %%
print(arrem)
# Out:
# ['yahoo.com', 'gmail.com', 'hotmail.com', 'baker.net', 'rodriguez.com', 'smith.com', 'yahoo.com', 'gmail.com', 'rodriguez.info', 'yahoo.com', 'gomez.org', 'yahoo.com', 'tyler.org', 'mendoza.info', 'yahoo.com', 'dougherty.info', 'williams.com', 'gmail.com', 'yahoo.com', 'aguilar-nelson.com', 'harrison.com', 'yahoo.com', 'sparks-woods.com', 'gilmore.com', 'yahoo.com', 'campbell-jones.net', 'obrien-mendoza.org', 'hughes.com', 'thomas-jordan.com', 'ellis.com', 'hotmail.com', 'kirby.net', 'owens.com', 'murray.net', 'hotmail.com', 'hanson-hayes.com', 'yahoo.com', 'yahoo.com', 'gmail.com', 'gmail.com', 'hotmail.com']
