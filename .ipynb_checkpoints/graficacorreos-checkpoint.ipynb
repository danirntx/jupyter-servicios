# %%
from faker import Faker
fake = Faker('es_ES')
fake.name()
from faker import Factory
import pandas as pd
import random
import os
import array as arr
from collections import Counter

# %%
arrem = []
nd = pd.DataFrame (
     {
        "Nombre":[fake.name()],
        "Correo":[fake.email()],
        "Direccion":[fake.country()],
        
      }
)

for i in range(random.randint(25,50)):
    stuff = [fake.name()
        , fake.email()
        , fake.country()]
    nd.loc[i] = [item for item in stuff]
    email = fake.email()
    global host
    host = email.split('@')[1]
    arrem.append(host)
    

df = nd

# %%
df
# Out:
#                              Nombre                                 Correo  \
# 0       Luis Miguel González Suárez                     mmarmol@gracia.com
# 1                Andrés Arco Quirós                    silvia91@bayona.com
# 2            Mohamed Barrera Bernad                aliciaplaza@hotmail.com
# 3           Miguel Ángel Torre Font            aguiloyolanda@arnau-bas.com
# 4     Asunción María Plana Barragán                     rosa94@hotmail.com
# 5               Sandra de Izaguirre                lourdesquiros@yahoo.com
# 6            Margarita Dávila-Lluch                  felix37@moll-rios.com
# 7           Josefina del Echevarría                 jorgevera@gual-mur.org
# 8   Pilar Encarnacion Fuente Burgos        torrijosjuan-manuel@hotmail.com
# 9          Esperanza Tolosa Asensio               franciscoandrea@roma.com
# 10     Mercedes Hernando Echevarría                 salvador78@hotmail.com
# 11                  Josep Tur Ramos                     felipe18@yahoo.com
# 12             Encarnacion Gil Mayo            jose-manuelalcala@gmail.com
# 13            Alicia Mínguez Conesa                     mrodrigo@yahoo.com
# 14        Jose Manuel Nieto Guitart                  eduardorius@gmail.com
# 15  Eduardo Joaquin Palmer Carrillo  jose-franciscopalau@recio-llorens.com
# 16      Juan Manuel Madrigal-Azorin                   noelia79@hotmail.com
# 17             Alvaro Ríos Figueras                aurorasainz@galiano.biz
# 18           Alfonso Torrens Segura           francisco-javier57@gmail.com
# 19               Marcos Robledo Tur               isabelchico@calderon.com
# 20               Jose Carlos Merino                     bjorda@ferrer.info
# 21              Marta Ramírez Pérez                      anna15@iborra.com
# 22              Juana Sancho Morata                       hduran@ramon.org
# 23                   Gema de Crespi                    zcatalan@patino.net
# 24                  Pedro Vilaplana                    sugarte@hotmail.com
# 25                     Salvador Cid                     ttorre@hotmail.com
# 26                 Daniela del Cruz           puentejose-ramon@hotmail.com
# 27          Concepción Gomez Esteve                  lucia36@corominas.com
# 28             Marcos Olmo Guerrero                 aitorescriva@yahoo.com
#
#                                           Direccion
# 0                                           Somalia
# 1                                            Bhután
# 2                                        Eslovaquia
# 3                                          Lituania
# 4                                           Noruega
# 5                                              Perú
# 6                          República Centroafricana
# 7                                        Mozambique
# 8                                        Costa Rica
# 9                                         Indonesia
# 10                                          Hungría
# 11                                          Camboya
# 12                                           Canadá
# 13                                           Mónaco
# 14                                         Suriname
# 15                                   Islas Marshall
# 16                                Brunei Darussalam
# 17                                          Lesotho
# 18                                    Côte d'Ivoire
# 19                                           Tuvalu
# 20                                       Cabo Verde
# 21                                      Santa Lucía
# 22                                Antigua y Barbuda
# 23                            Santo Tomé y Príncipe
# 24                                         Islandia
# 25                                            Palau
# 26                                        Argentina
# 27                                           Guyana
# 28  Reino Unido de Gran Bretaña e Irlanda del Norte

# %%
print(arrem)
# Out:
# ['hotmail.com', 'yahoo.com', 'poza.com', 'blanca.org', 'yahoo.com', 'hotmail.com', 'hervas.com', 'anaya-blazquez.net', 'rius-guillen.biz', 'yahoo.com', 'segarra-ramirez.org', 'hotmail.com', 'sanz-sarabia.net', 'gmail.com', 'mendez-quintero.org', 'cerro.org', 'hotmail.com', 'mercader.com', 'martin-barrios.org', 'sancho.com', 'gmail.com', 'gmail.com', 'yahoo.com', 'perales-abella.info', 'moreno.biz', 'hotmail.com', 'yahoo.com', 'gmail.com', 'hotmail.com']

# %%
arr = {i:arrem.count(i) for i in arrem}
arr
# Out:
# {'hotmail.com': 6,
#  'yahoo.com': 5,
#  'poza.com': 1,
#  'blanca.org': 1,
#  'hervas.com': 1,
#  'anaya-blazquez.net': 1,
#  'rius-guillen.biz': 1,
#  'segarra-ramirez.org': 1,
#  'sanz-sarabia.net': 1,
#  'gmail.com': 4,
#  'mendez-quintero.org': 1,
#  'cerro.org': 1,
#  'mercader.com': 1,
#  'martin-barrios.org': 1,
#  'sancho.com': 1,
#  'perales-abella.info': 1,
#  'moreno.biz': 1}

# %%
da = pd.Series(arr).to_frame()
db = da.reset_index()
db.columns = ['Correos', 'Cantidad']
db
# Out:
#                 Correos  Cantidad
# 0           hotmail.com         6
# 1             yahoo.com         5
# 2              poza.com         1
# 3            blanca.org         1
# 4            hervas.com         1
# 5    anaya-blazquez.net         1
# 6      rius-guillen.biz         1
# 7   segarra-ramirez.org         1
# 8      sanz-sarabia.net         1
# 9             gmail.com         4
# 10  mendez-quintero.org         1
# 11            cerro.org         1
# 12         mercader.com         1
# 13   martin-barrios.org         1
# 14           sancho.com         1
# 15  perales-abella.info         1
# 16           moreno.biz         1

# %%
db.plot(x='Correos', y='Cantidad', kind='bar');
